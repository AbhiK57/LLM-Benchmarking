# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiK57/LLM-Benchmarking/blob/main/SGLang_Bench.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "transformers>=4.44.2" "tokenizers>=0.19.1" "pynvml" "pandas" "torch" "gpustat" "nvidia-ml-py3"
# !pip install --upgrade "sglang[cuda12x]>=0.3.1"
# Out:
# Requirement already satisfied: sglang>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from sglang[cuda12x]>=0.3.1) (0.5.3.post1)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (7.34.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.13.0)
# Requirement already satisfied: anthropic>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.69.0)
# Requirement already satisfied: blobfile==3.0.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.0.0)
# Requirement already satisfied: build in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.0)
# Requirement already satisfied: compressed-tensors in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.12.2)
# Requirement already satisfied: cuda-python in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (13.0.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.0.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.8.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.118.2)
# Requirement already satisfied: flashinfer_python==0.4.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.4.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.9)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.35.3)
# Requirement already satisfied: interegular in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.3.3)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.30)
# Requirement already satisfied: modelscope in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.30.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.19.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.0.2)
# Requirement already satisfied: nvidia-cutlass-dsl==4.2.1 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.2.1)
# Requirement already satisfied: openai-harmony==0.0.4 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.0.4)
# Requirement already satisfied: openai==1.99.1 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.99.1)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.11.3)
# Requirement already satisfied: outlines==0.1.11 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.11)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (25.0)
# Requirement already satisfied: partial_json_parser in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.2.1.1.post6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (11.3.0)
# Requirement already satisfied: prometheus-client>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (5.9.5)
# Requirement already satisfied: py-spy in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.4.1)
# Requirement already satisfied: pybase64 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.4.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.11.10)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.0.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.0.20)
# Requirement already satisfied: pyzmq>=25.1.2 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (26.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.32.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.16.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.2.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.7)
# Requirement already satisfied: sgl-kernel==0.3.15 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.3.15)
# Requirement already satisfied: soundfile==0.13.1 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.13.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.12.0)
# Requirement already satisfied: timm==1.0.16 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.0.16)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.8.0+cu126)
# Requirement already satisfied: torch_memory_saver==0.0.9rc2 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.0.9rc2)
# Requirement already satisfied: torchao==0.9.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.9.0)
# Requirement already satisfied: torchaudio==2.8.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.23.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.67.1)
# Requirement already satisfied: transformers==4.57.0 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.57.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.37.0)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.21.0)
# Requirement already satisfied: xgrammar==0.1.25 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.25)
# Requirement already satisfied: grpcio==1.75.1 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.75.1)
# Requirement already satisfied: grpcio-tools==1.75.1 in /usr/local/lib/python3.12/dist-packages (from sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.75.1)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.12/dist-packages (from blobfile==3.0.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.23.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from blobfile==3.0.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.5.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.12/dist-packages (from blobfile==3.0.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (5.4.0)
# Requirement already satisfied: filelock>=3.0 in /usr/local/lib/python3.12/dist-packages (from blobfile==3.0.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.20.0)
# Requirement already satisfied: apache-tvm-ffi==0.1.0b15 in /usr/local/lib/python3.12/dist-packages (from flashinfer_python==0.4.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.0b15)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from flashinfer_python==0.4.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (8.3.0)
# Requirement already satisfied: nvidia-cudnn-frontend>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from flashinfer_python==0.4.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.15.0)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from flashinfer_python==0.4.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.575.51)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from flashinfer_python==0.4.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio==1.75.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.15.0)
# Requirement already satisfied: protobuf<7.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from grpcio-tools==1.75.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (6.32.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from grpcio-tools==1.75.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (75.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.1.6)
# Requirement already satisfied: lark in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.1.1)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.25.1)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (20250909)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.26)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile==0.13.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm==1.0.16->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (6.0.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm==1.0.16->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.6.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.22.1)
# WARNING: sglang 0.5.3.post1 does not provide the extra 'cuda12x'
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.17.0)
# Requirement already satisfied: cuda-bindings~=13.0.2 in /usr/local/lib/python3.12/dist-packages (from cuda-python->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (13.0.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-python->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.22.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.2.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.12/dist-packages (from compressed-tensors->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.70.16)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2025.10.5)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.48.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (4.9.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile==0.13.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.23)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.99.1->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->outlines==0.1.11->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->sglang>=0.3.1->sglang[cuda12x]>=0.3.1) (1.17.0)

# %%
import sglang as sgl
import asyncio
from google.colab import userdata
import os
import torch
from pynvml import *
import time
import threading
import pandas as pd
from transformers import AutoTokenizer
from pynvml import nvmlInit, nvmlShutdown, nvmlDeviceGetHandleByIndex, nvmlDeviceGetPowerUsage, nvmlDeviceGetMemoryInfo
from google.colab import files

# %%
hf_token = userdata.get('HF_TOKEN')
MODEL_ID = "meta-llama/Llama-3.2-1B-Instruct"
os.environ["HUGGING_FACE_HUB_TOKEN"] = hf_token
backend = sgl.Runtime(model_path=MODEL_ID,
                      tokenizer_path=MODEL_ID,
                      dtype=torch.bfloat16,
                      tp_size=1)
sgl.set_default_backend(backend)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
@sgl.function
def ask_question(s, topic):
    s += sgl.user(f"Tell me a fun fact about {topic}.")
    s += sgl.assistant(sgl.gen("answer", max_tokens=256))

# %%
state = ask_question(topic="the planet Jupiter")
response = state["answer"]
print(response)
# Out:
# Here's a fun fact about Jupiter:
#
# Jupiter is the largest planet in our solar system by volume! That's even bigger than the rock that the planet is made of – ice and hydrogen! In fact, it's so massive that it is more than 1,300 times the mass of Earth. To put it in perspective, the diameter of Jupiter is about 11 times the diameter of the Earth. That's a golf ball-sized planet!

# %%
nvmlInit()
gpu_handle = nvmlDeviceGetHandleByIndex(0)

def read_gpu_power_watts():
    return nvmlDeviceGetPowerUsage(gpu_handle) / 1000.0

def read_gpu_mem():
    info = nvmlDeviceGetMemoryInfo(gpu_handle)
    return dict(used=info.used, total=info.total, util=info.used/info.total)

class PowerSampler:
    def __init__(self, interval=0.2):
        self.interval=interval
        self.samples=[]
        self._stop=threading.Event()
        self._t=None
    def _run(self):
        while not self._stop.is_set():
            try:
                self.samples.append((time.time(), read_gpu_power_watts()))
            except: pass
            time.sleep(self.interval)
    def stop(self):
        self._stop.set(); self._t.join()
    def stats(self):
        vals = [p for _, p in self.samples]
        if not vals:
            return dict(avg_power=None, peak_power=None)
        return dict(avg_power=sum(vals)/len(vals), peak_power=max(vals))

    def start(self):
        self.samples.clear(); self._stop.clear()
        self._t = threading.Thread(target=self._run, daemon=True); self._t.start()
        time.sleep(0.05)  # tiny warmup to likely capture at least one sample

# %%
PROMPT_SIZES = [10, 25, 50]                 # target input tokens
BATCH_SIZES  = [1, 10, 25]                   # number of prompts per run
FIXED_OUTPUT =  128  # max new tokens

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)

# %%
# @title Helper Functions
def make_prompt(n_tokens: int, seed="You are a helpful assistant."):
    """Generates a prompt with a target number of tokens."""
    text = seed
    while len(tokenizer.encode(text, add_special_tokens=False)) < n_tokens:
        text += " The quick brown fox jumps over the lazy dog."
    # Truncate to the exact number of tokens
    encoded = tokenizer.encode(text, add_special_tokens=False)[:n_tokens]
    return tokenizer.decode(encoded)

# %%
@sgl.function
def generate_text(s, prompt):
    s += sgl.user(prompt)
    s += sgl.assistant(sgl.gen("output", max_tokens=FIXED_OUTPUT, temperature=0.0))

# %%
# @title Benchmark Runner Logic
def run_sglang_batch(prompts, max_new_tokens=128):
    """
    Runs a batch of prompts using SGLang and measures performance.
    """
    ps = PowerSampler(); ps.start()
    mem_before = read_gpu_mem(); t0 = time.time()

    # --- SGLang Batch Inference ---
    #create list of asynchronous generation requests
    requests = [generate_text(prompt=p) for p in prompts]
    #execute
    _ = [st["output"] for st in requests]

    t1 = time.time(); ps.stop()
    mem_after = read_gpu_mem(); s = ps.stats(); total = t1 - t0

    return dict(
        latency_s=total / len(prompts),
        total_s=total,
        qps=len(prompts) / total,
        avg_power_w=s["avg_power"],
        peak_power_w=s["peak_power"],
        mem_before=mem_before["used"],
        mem_after=mem_after["used"]
    )

# %%
rows = []
backend_name = "sglang"

print(f"--- Running benchmarks for {backend_name.upper()} ---")

for n in PROMPT_SIZES:
    for b in BATCH_SIZES:
        prompts = [make_prompt(n) for _ in range(b)]
        print(f"  → prompt={n} tokens | batch={b}")
        try:
            result = run_sglang_batch(prompts, FIXED_OUTPUT)
            result.update(dict(backend=backend_name, prompt_tokens=n, batch_size=b, output_tokens=FIXED_OUTPUT))
            rows.append(result)
        except Exception as e:
            print(f"Error for {backend_name} n={n} b={b}: {e}")
            # Optional: Add more detailed error logging if needed
            # import traceback
            # traceback.print_exc()

# @title Save and Display Results
df = pd.DataFrame(rows)
output_filename = "/content/sglang_results.csv"
df.to_csv(output_filename, index=False)
print(f"\n Benchmark complete! Saved to {output_filename}")
# Out:
# --- Running benchmarks for SGLANG ---
#   → prompt=10 tokens | batch=1
#   → prompt=10 tokens | batch=10
#   → prompt=10 tokens | batch=25
#   → prompt=25 tokens | batch=1
#   → prompt=25 tokens | batch=10
#   → prompt=25 tokens | batch=25
#   → prompt=50 tokens | batch=1
#   → prompt=50 tokens | batch=10
#   → prompt=50 tokens | batch=25
#
#  Benchmark complete! Saved to /content/sglang_results.csv

# %%
display(df)
# Out:
#    latency_s   total_s         qps  avg_power_w  peak_power_w   mem_before  \
# 0   0.233016  0.233016    4.291559      94.9875       141.375  39070859264
# 1   0.026124  0.261242   38.278732     131.5015       199.557  39070859264
# 2   0.011972  0.299308   83.526116     132.9630       201.018  39070859264
# 3   0.256871  0.256871    3.893001     157.6895       209.998  39070859264
# 4   0.044908  0.449080   22.267760     156.7130       201.018  39070859264
# 5   0.013619  0.340478   73.426195     120.5940       174.548  39070859264
# 6   0.043957  0.043957   22.749755     211.4580       211.458  39070859264
# 7   0.006961  0.069609  143.660227      79.7540        79.754  39070859264
# 8   0.004084  0.102107  244.842224      64.9080        64.908  39070859264
#
#      mem_after backend  prompt_tokens  batch_size  output_tokens
# 0  39070859264  sglang             10           1            128
# 1  39070859264  sglang             10          10            128
# 2  39070859264  sglang             10          25            128
# 3  39070859264  sglang             25           1            128
# 4  39070859264  sglang             25          10            128
# 5  39070859264  sglang             25          25            128
# 6  39070859264  sglang             50           1            128
# 7  39070859264  sglang             50          10            128
# 8  39070859264  sglang             50          25            128
